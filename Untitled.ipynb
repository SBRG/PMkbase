# %%
import pandas as pd

# %%
df = pd.read_csv('df2.tsv',sep='\t')
df
# Out:
#      PlateIDs Strain   Specie Well Plate         Media Replicates  \
# 0        ECP1   ELI3  E. coli  A01  PM01  M9 No carbon         R1
# 1        ECP1   ELI3  E. coli  A02  PM01  M9 No carbon         R1
# 2        ECP1   ELI3  E. coli  A03  PM01  M9 No carbon         R1
# 3        ECP1   ELI3  E. coli  A04  PM01  M9 No carbon         R1
# 4        ECP1   ELI3  E. coli  A05  PM01  M9 No carbon         R1
# ...       ...    ...      ...  ...   ...           ...        ...
# 1051    ECP17  EC150  E. coli  H08  PM01  M9 No Carbon         R4
# 1052    ECP17  EC150  E. coli  H09  PM01  M9 No Carbon         R4
# 1053    ECP17  EC150  E. coli  H10  PM01  M9 No Carbon         R4
# 1054    ECP17  EC150  E. coli  H11  PM01  M9 No Carbon         R4
# 1055    ECP17  EC150  E. coli  H12  PM01  M9 No Carbon         R4
#
#                          Compound                 Description KEGG ID  \
# 0                Negative Control  C-Source, negative control     NaN
# ...

# %%
df[df['Strain Replicate']=='EC150 R2']
# Out:
#     PlateIDs Strain   Specie Well Plate         Media Replicates  \
# 384     ECP7  EC150  E. coli  A01  PM01  M9-No Carbon         R2
# 385     ECP7  EC150  E. coli  A02  PM01  M9-No Carbon         R2
# 386     ECP7  EC150  E. coli  A03  PM01  M9-No Carbon         R2
# 387     ECP7  EC150  E. coli  A04  PM01  M9-No Carbon         R2
# 388     ECP7  EC150  E. coli  A05  PM01  M9-No Carbon         R2
# ..       ...    ...      ...  ...   ...           ...        ...
# 859    ECP15  EC150  E. coli  H08  PM01  M9 No Carbon         R2
# 860    ECP15  EC150  E. coli  H09  PM01  M9 No Carbon         R2
# 861    ECP15  EC150  E. coli  H10  PM01  M9 No Carbon         R2
# 862    ECP15  EC150  E. coli  H11  PM01  M9 No Carbon         R2
# 863    ECP15  EC150  E. coli  H12  PM01  M9 No Carbon         R2
#
#                         Compound                 Description KEGG ID  \
# 384             Negative Control  C-Source, negative control     NaN
# ...
